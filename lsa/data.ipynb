# %%
import os.path
import pandas as pd


def select_plots(output_file, min_year=1990, max_rows=1000, seed=42):
    folder = 'raw_data'
    file = 'wiki_movie_plots_deduped.csv'
    csv_path = os.path.join(folder, file)
    
    df = pd.read_csv(csv_path)
    
    df = df[df['Release Year'] > min_year]
    df = df[df['Director'] != 'Unknown']
    
    countries = ['American', 'British', 'Japanese', 'Canadian']
    genres = ['drama', 'comedy', 'romance', 'action', 'romantic comedy', 'comedy-drama', 'crime drama', 'thriller', 'science fiction']
    
    df = df[df['Genre'].isin(genres)]
    df = df[df['Origin/Ethnicity'].isin(countries)]
    
    # count director -> film count
    film_count = df.groupby(['Director']).count().Title.to_dict()
    # map director -> film count
    df['movies'] = df['Director'].map(film_count)
    
    df = df.sort_values('movies', ascending=False)[:max_rows]
    
    # for compatibility with current code
    df.rename(columns={
        'Title': 'title',
        'Director': 'author',
        'Wiki Page': 'link',
        'Plot': 'content'
    })

    df.to_csv(output_file, header=True, index=False)
    print('articles saved to', output_file)
    return df

# %%
select_plots('data/plots.csv')
# Out:
#        Release Year               Title Origin/Ethnicity         Director  \
# 14716          2005         Match Point         American      Woody Allen
# 16454          2013        Blue Jasmine         American      Woody Allen
# 15171          2007   Cassandra's Dream         American      Woody Allen
# 11811          1992  Husbands and Wives         American      Woody Allen
# 13740          2000   Small Time Crooks         American      Woody Allen
# ...             ...                 ...              ...              ...
# 12291          1994     Renaissance Man         American   Penny Marshall
# 12304          1994          Serial Mom         American      John Waters
# 12305          1994          The Shadow         American  Russell Mulcahy
# 16298          2012        Hope Springs         American    David Frankel
# 16292          2012      The Guilt Trip         American    Anne Fletcher
#
#                                                     Cast        Genre  \
# 14716  Jonathan Rhys Meyers, Scarlett Johansson, Emil...  crime drama
# 16454  Alec Baldwin, Cate Blanchett, Louis C.K., Bobb...        drama
# 15171  Hayley Atwell, Colin Farrell, Sally Hawkins, E...        drama
# 11811  Woody Allen, Mia Farrow, Judy Davis, Sydney Po...        drama
# 13740             Woody Allen, Hugh Grant, Tracey Ullman       comedy
# ...                                                  ...          ...
# 12291  Danny DeVito, Gregory Hines, Mark Wahlberg, Cl...       comedy
# 12304  Kathleen Turner, Sam Waterston, Ricki Lake, Ma...       comedy
# 12305       Alec Baldwin, John Lone, Penelope Ann Miller       action
# 16298        Meryl Streep, Tommy Lee Jones, Steve Carell       comedy
# 16292                       Barbra Streisand, Seth Rogen       comedy
#
#                                                Wiki Page  \
# 14716          https://en.wikipedia.org/wiki/Match_Point
# 16454         https://en.wikipedia.org/wiki/Blue_Jasmine
# 15171  https://en.wikipedia.org/wiki/Cassandra%27s_Dream
# 11811   https://en.wikipedia.org/wiki/Husbands_and_Wives
# 13740    https://en.wikipedia.org/wiki/Small_Time_Crooks
# ...                                                  ...
# 12291  https://en.wikipedia.org/wiki/Renaissance_Man_...
# 12304           https://en.wikipedia.org/wiki/Serial_Mom
# 12305  https://en.wikipedia.org/wiki/The_Shadow_(1994...
# 16298  https://en.wikipedia.org/wiki/Hope_Springs_(20...
# 16292  https://en.wikipedia.org/wiki/The_Guilt_Trip_(...
#
#                                                     Plot  movies
# 14716  Chris Wilton, a recently retired tennis profes...      18
# 16454  Jasmine Francis (Cate Blanchett) disembarks in...      18
# 15171  Brothers Terry (Colin Farrell) and Ian (Ewan M...      18
# 11811  The film is about two couples: Jack (Pollack) ...      18
# 13740  Career criminal Ray (Woody Allen) and his cron...      18
# ...                                                  ...     ...
# 12291  Bill Rago (DeVito) is a divorced advertising e...       4
# 12304  Beverly Sutphin appears to be a typical suburb...       4
# 12305  In Tibet, following the First World War, an Am...       4
# 16298  Although a devoted couple, empty nesters Kay a...       4
# 16292  Andy Brewster (Seth Rogen) is a UCLA-graduate ...       4
#
# [1000 rows x 9 columns]

# %%
folder = 'raw_data'
file = 'wiki_movie_plots_deduped.csv'
csv_path = os.path.join(folder, file)

df = pd.read_csv(csv_path)

df = df[df['Release Year'] > min_year]
df = df[df['Director'] != 'Unknown']

# %%
df.groupby(['Director']).count().sort_values('Title', ascending=False)
# Out:
#                  Release Year  Title  Origin/Ethnicity  Cast  Genre  \
# Director
# P. Vasu                    35     35                35    35     35
# Priyadarshan               32     32                32    32     32
# K. S. Ravikumar            29     29                29    29     29
# Ram Gopal Varma            28     28                28    28     28
# David Dhawan               27     27                27    27     27
# ...                       ...    ...               ...   ...    ...
# Jameson Lam                 1      1                 1     1      1
# James Yukich                1      1                 1     1      1
# James Watkins               1      1                 1     1      1
# James Tucker                1      1                 1     1      1
# Пятница                     1      1                 1     1      1
#
#                  Wiki Page  Plot
# Director
# P. Vasu                 35    35
# Priyadarshan            32    32
# K. S. Ravikumar         29    29
# Ram Gopal Varma         28    28
# David Dhawan            27    27
# ...                    ...   ...
# Jameson Lam              1     1
# James Yukich             1     1
# James Watkins            1     1
# James Tucker             1     1
# Пятница                  1     1
#
# [8719 rows x 7 columns]

# %%
df.groupby(['Genre']).count().sort_values('Title', ascending=False).nlargest(10, 'Title')
# Out:
#                  Release Year  Title  Origin/Ethnicity  Director  Cast  \
# Genre
# unknown                  3218   3218              3218      3218  3071
# drama                    2320   2320              2320      2320  2275
# comedy                   1719   1719              1719      1719  1706
# action                    753    753               753       753   747
# romance                   650    650               650       650   647
# thriller                  580    580               580       580   576
# horror                    573    573               573       573   557
# romantic comedy           255    255               255       255   251
# crime drama               208    208               208       208   208
# science fiction           183    183               183       183   175
#
#                  Wiki Page  Plot
# Genre
# unknown               3218  3218
# drama                 2320  2320
# comedy                1719  1719
# action                 753   753
# romance                650   650
# thriller               580   580
# horror                 573   573
# romantic comedy        255   255
# crime drama            208   208
# science fiction        183   183

# %%
df.groupby(['Origin/Ethnicity']).count().sort_values('Title', ascending=False).nlargest(10, 'Title')
# Out:
#                   Release Year  Title  Director  Cast  Genre  Wiki Page  Plot
# Origin/Ethnicity
# American                  5740   5740      5740  5683   5740       5740  5740
# Tamil                     1569   1569      1569  1539   1569       1569  1569
# Bollywood                 1432   1432      1432  1427   1432       1432  1432
# British                   1163   1163      1163  1137   1163       1163  1163
# Malayalam                 1059   1059      1059  1056   1059       1059  1059
# Telugu                     861    861       861   861    861        861   861
# Japanese                   693    693       693   536    693        693   693
# Canadian                   533    533       533   511    533        533   533
# Chinese                    456    456       456   436    456        456   456
# Hong Kong                  448    448       448   407    448        448   448

# %%
countries = ['American', 'British', 'Japanese', 'Canadian']

# %%
genres = ['drama', 'comedy', 'romance', 'action', 'romantic comedy', 'comedy-drama', 'crime drama', 'thriller', 'science fiction']

# %%
df = df[df['Genre'].isin(genres)]

# %%
df = df[df['Origin/Ethnicity'].isin(countries)]

# %%
df.shape
# Out:
# (4021, 8)

# %%
df.groupby(['Director']).count().sort_values('Title', ascending=False)
# Out:
#                 Release Year  Title  Origin/Ethnicity  Cast  Genre  Wiki Page  \
# Director
# Woody Allen               18     18                18    18     18         18
# Dennis Dugan              12     12                12    12     12         12
# Garry Marshall            10     10                10    10     10         10
# Clint Eastwood            10     10                10    10     10         10
# Spike Lee                 10     10                10    10     10         10
# ...                      ...    ...               ...   ...    ...        ...
# James Wong                 1      1                 1     1      1          1
# James Wan                  1      1                 1     1      1          1
# James Rogers               1      1                 1     1      1          1
# James Ricardo              1      1                 1     1      1          1
# Éva Gárdos                 1      1                 1     1      1          1
#
#                 Plot  movies
# Director
# Woody Allen       18       0
# Dennis Dugan      12       0
# Garry Marshall    10       0
# Clint Eastwood    10       0
# Spike Lee         10       0
# ...              ...     ...
# James Wong         1       0
# James Wan          1       0
# James Rogers       1       0
# James Ricardo      1       0
# Éva Gárdos         1       0
#
# [2377 rows x 8 columns]

# %%
# director -> film count
film_count = df.groupby(['Director']).count().Title.to_dict()

# %%
# map director with film count
df['movies'] = df['Director'].map(film_count)

# %%
max_rows = 1000

# %%
df.sort_values('movies', ascending=False)[:max_rows]
# Out:
#        Release Year               Title Origin/Ethnicity         Director  \
# 14716          2005         Match Point         American      Woody Allen
# 16454          2013        Blue Jasmine         American      Woody Allen
# 15171          2007   Cassandra's Dream         American      Woody Allen
# 11811          1992  Husbands and Wives         American      Woody Allen
# 13740          2000   Small Time Crooks         American      Woody Allen
# ...             ...                 ...              ...              ...
# 12291          1994     Renaissance Man         American   Penny Marshall
# 12304          1994          Serial Mom         American      John Waters
# 12305          1994          The Shadow         American  Russell Mulcahy
# 16298          2012        Hope Springs         American    David Frankel
# 16292          2012      The Guilt Trip         American    Anne Fletcher
#
#                                                     Cast        Genre  \
# 14716  Jonathan Rhys Meyers, Scarlett Johansson, Emil...  crime drama
# 16454  Alec Baldwin, Cate Blanchett, Louis C.K., Bobb...        drama
# 15171  Hayley Atwell, Colin Farrell, Sally Hawkins, E...        drama
# 11811  Woody Allen, Mia Farrow, Judy Davis, Sydney Po...        drama
# 13740             Woody Allen, Hugh Grant, Tracey Ullman       comedy
# ...                                                  ...          ...
# 12291  Danny DeVito, Gregory Hines, Mark Wahlberg, Cl...       comedy
# 12304  Kathleen Turner, Sam Waterston, Ricki Lake, Ma...       comedy
# 12305       Alec Baldwin, John Lone, Penelope Ann Miller       action
# 16298        Meryl Streep, Tommy Lee Jones, Steve Carell       comedy
# 16292                       Barbra Streisand, Seth Rogen       comedy
#
#                                                Wiki Page  \
# 14716          https://en.wikipedia.org/wiki/Match_Point
# 16454         https://en.wikipedia.org/wiki/Blue_Jasmine
# 15171  https://en.wikipedia.org/wiki/Cassandra%27s_Dream
# 11811   https://en.wikipedia.org/wiki/Husbands_and_Wives
# 13740    https://en.wikipedia.org/wiki/Small_Time_Crooks
# ...                                                  ...
# 12291  https://en.wikipedia.org/wiki/Renaissance_Man_...
# 12304           https://en.wikipedia.org/wiki/Serial_Mom
# 12305  https://en.wikipedia.org/wiki/The_Shadow_(1994...
# 16298  https://en.wikipedia.org/wiki/Hope_Springs_(20...
# 16292  https://en.wikipedia.org/wiki/The_Guilt_Trip_(...
#
#                                                     Plot  movies
# 14716  Chris Wilton, a recently retired tennis profes...      18
# 16454  Jasmine Francis (Cate Blanchett) disembarks in...      18
# 15171  Brothers Terry (Colin Farrell) and Ian (Ewan M...      18
# 11811  The film is about two couples: Jack (Pollack) ...      18
# 13740  Career criminal Ray (Woody Allen) and his cron...      18
# ...                                                  ...     ...
# 12291  Bill Rago (DeVito) is a divorced advertising e...       4
# 12304  Beverly Sutphin appears to be a typical suburb...       4
# 12305  In Tibet, following the First World War, an Am...       4
# 16298  Although a devoted couple, empty nesters Kay a...       4
# 16292  Andy Brewster (Seth Rogen) is a UCLA-graduate ...       4
#
# [1000 rows x 9 columns]
